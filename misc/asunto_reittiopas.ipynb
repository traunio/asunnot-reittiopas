# %%
# %matplotlib inline
import requests
import json
import urllib
import pprint
from datetime import date
from datetime import timedelta
import statistics as st
import itertools as it

import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm

# %%
d = []

for i in range(11):
    c = cm.Accent(i/12,0.8)
    pprint.pprint('(%i, %i, %i)' % (c[0]*255, c[1]*255, c[2]*255))
    d.append([int(255*c[0]), int(255*c[1]), int(255*c[2])])
print(d)
# Out:
# '(127, 201, 127)'
# '(163, 185, 176)'
# '(199, 176, 200)'
# '(237, 187, 152)'
# '(253, 213, 140)'
# '(254, 249, 151)'
# '(152, 179, 164)'
# '(72, 98, 171)'
# '(178, 37, 143)'
# '(226, 26, 98)'
# '(198, 77, 38)'
# [[127, 201, 127], [163, 185, 176], [199, 176, 200], [237, 187, 152], [253, 213, 140], [254, 249, 151], [152, 179, 164], [72, 98, 171], [178, 37, 143], [226, 26, 98], [198, 77, 38]]

# %%
print([x for x in zip([1,2,3,4],['a','b','c','d'], ['a1','b2','c3'])])
# Out:
# [(1, 'a', 'a1'), (2, 'b', 'b2'), (3, 'c', 'c3')]

# %%
#payload, date and time to be included
#date format: "2016-05-20",
#time format: "23:28:00"
ROUTEQ = """
{
  plan(from: {lat: %s, lon: %s}, 
       to: {lat: %s, lon: %s},
       modes: "BUS,TRAM,RAIL,SUBWAY,FERRY,WALK",
       walkReluctance: 2.1, walkBoardCost: 600,
       minTransferTime: 180, walkSpeed: 1.2,
       numItineraries: 11,
       date: "%s",
       time: "%s"
       ) {
   itineraries{
      startTime
      walkDistance
      duration
      legs {
        mode
        startTime
        endTime
        duration       
        distance
        from {stop {
          gtfsId
        }}
        trip {tripHeadsign}
        route {
          shortName            
        }
        }       
    }
  }  
}"""      
  

# for checking walk duration and distance
WALKQ = """
{
  plan(from: {lat: %s, lon: %s}, 
       to: {lat: %s, lon: %s},
       modes: "WALK",
       ) {
   itineraries{
      startTime
      walkDistance
      duration       
    }
  }  
}"""  

# date in format e.g. "20160929"
STOPQ = """
{
  stop(id: "%s") {
    stoptimesForServiceDate(date: "%s") { 
      pattern {
        headsign
        route {
          shortName
        }
      }
      stoptimes {
        scheduledDeparture
      }
    }
  } 
}"""

def runQuery(payload):
    req = requests.Request('POST', "https://api.digitransit.fi/routing/v1/routers/hsl/index/graphql", data=payload)
#req = requests.Request('POST', "https://httpbin.org/post", data=payload) # for debugging
    prepped = req.prepare()
    prepped.headers['Content-Type']='application/graphql'
    s = requests.Session()
    resp = s.send(prepped)

    if resp.status_code == 200: # response code ok
        try:
            reslist = resp.json()
            return reslist
        except:
            return None
    else:
        return None

# Input: address as string
# Output: (latitude, longitude) or None
# Gives a latitude longitude pair for a given text address
def getLocation(address):
    payload = "http://api.digitransit.fi/geocoding/v1/search?text=" + urllib.parse.quote(address) # + "&size=1"
    payload = payload + "&focus.point.lat=60.169856&focus.point.lon=24.938379&size=5"
    data = requests.get(payload)
    json_reply = data.json()
    try:
        results = {}
        for i in json_reply['features']:
            coord = i['geometry']['coordinates']
            place = i['properties']['label']
            ok_cities = ["Espoo", "Helsinki", "Kauniainen", "Vantaa", "Kirkkonummi"]
            # print("Debug: %s and coords %s" % (place,coord)) 
            for city in ok_cities:
                if city in place:
                    results[place] = (coord[1],coord[0])
                    break

        return results

    except:
        return None

# reverse search mainly for testing purposes
def getStreetName(coords):
    lat, lon = coords
    lat = str(lat)
    lon = str(lon)
    payload = "http://api.digitransit.fi/geocoding/v1/reverse?point.lat=" + lat + "&point.lon=" + lon +"&size=1"
    response = requests.get(payload)

    # try to find a specific field in json respons. Return None if not successful
    try:
        return response.json()['features'][0]['properties']['label']
    except:
        return None

# %%
class CheckRoutes():
    
    def __init__(self, places):         
        self.places = places        
        # self.updatePlaces()
       
    # separate method, since it will result in queries to digitransit
    def updatePlaces(self):       
        self.coordinates = {}
        for address in self.places:
            results = getLocation(address)
            # pprint.pprint(results)
            self.coordinates[address] = list(results.values())[0]
    
    
    # main function of the class
    def checkRoutes(self,address):        
        
        result = getLocation(address)
        poi = list(result.values())[0]
        self.poi = poi
        
        today = date.today()
        days = [today + timedelta(days=x) for x in range(1,8)]
        days = {x.isoweekday():x.strftime("%Y-%m-%d") for x in days}
        time = "07:30:00"
        datte = days[1] #1 is for Monday
        
        results = []

        for k,v in self.coordinates.items():
            
            print("\n\nFrom %s to %s" % (address,k))
            
            payload = ROUTEQ % (poi[0],poi[1],v[0],v[1],datte,time)
            result = runQuery(payload)['data']['plan']['itineraries'] # (durations,singleroutes,longerroutes)
            (dure,singles,longer) = self.analyseRouteQ(result)
            results.append((address,k,dure,singles,longer))
            
            self.alltimes = [self.analyseSingle(k,v) for k,v in singles.items()]
            self.alltimes.extend([self.analyseMulti(k,v) for k,v in longer.items()])
        
            self.makeResults(self.alltimes, address,k)
        
        self.results=results
    
    # input is the results from runRouteQ
    def analyseRouteQ(self, reslist):        
        
        firstlist = [(x['startTime'],x['startTime']+x['duration']*1000) for x in reslist]
        
        # here we try to find routes, which leave later and arrive sooner. If we find such, return False
        noBetterRoutes = lambda x: False if [y for y in firstlist if x[1] >= y[1] and x[0] < y[0] ] else True
        
        # lambda function check that there are no faster routes
        filteredlist = [x for x in firstlist if noBetterRoutes(x)]       
        
        try:
            startTimes = [x[0] for x in filteredlist]
            firstStart = min(startTimes)
            lastStart = max(startTimes)
            times = (len(filteredlist)-1)/((lastStart - firstStart)/3600000)
         #   pprint.pprint("Average times %.1f in an hour" % times)
            
        except:
            pprint.pprint("Something went wrong")
            pprint.pprint(firstlist)
            pprint.pprint(filteredlist)
        
        durations = [(x[1]-x[0])/1000 for x in filteredlist] 
       
        
        ave_dure = st.median(durations)/60
        max_dure = max(durations)/60
        min_dure = min(durations)/60
        
        #pprint.pprint("Median duration %.1f mins" % ave_dure)
        #pprint.pprint("Max duration %.1f mins" % max_dure)
        #pprint.pprint("Min duration %.1f mins" % min_dure)

        singleroutes = {}
        longerroutes = {}
        for route in reslist:
            duration = route['duration']
            startTime = route['startTime'] # unit is [microseconds from Unix epoch]
            if route['legs'][0]['mode'] == 'WALK': # It's possible, that the trip starts from station/stop. Hence test
                startShift = route['legs'][0]['duration'] # unit is [s]
            else:
                startShift = 0
            walkDistance = route['walkDistance'] # unit is [m]

            legs = [x for x in route['legs'] if x['mode'] != 'WALK'] # for calculating legs without walking
            shortis = [x['route']['shortName'] if x['route']['shortName'] else x['mode'] \
                       + ' (' + x['trip']['tripHeadsign'] + ')' \
                       for x in route['legs'] if x['route'] != None]       

            if len(legs) < 2 and shortis:
                shortName = shortis[0]
                
                mode = legs[0]['mode']
                gtfsId = legs[0]['from']['stop']['gtfsId']
                if not shortName in singleroutes.keys():
                    singleroutes[shortName] = {'gtfsId':gtfsId, 'mode':mode, 'duration':duration, 'startTime':startTime,
                                           'startShift':startShift, 'walkDistance':walkDistance}
                
            elif shortis:
                try:
                    shortNames = '+'.join(shortis)
                except:
                    pprint.pprint(shortis)
                    pprint.pprint(route)
                if not shortNames in longerroutes.keys():
                    longerroutes[shortNames] = route                    

        return (durations,singleroutes,longerroutes)
    
    # combine multi legged route into one
    def analyseMulti(self,name, legs,weekday=1):
        today = date.today()
        days = [today + timedelta(days=x) for x in range(1,8)]
        days = {x.isoweekday():x.strftime("%Y%m%d") for x in days}  
        
        datte = days[1]
        
        legs = legs['legs']
        if legs[0]['mode'] == 'WALK':
            startshift = legs[0]['duration']
        else:
            startshift = 0

        stopinfo = lambda x: (x['from']['stop']['gtfsId'], x['route']['shortName'], x['trip']['tripHeadsign'])
        stops2 = [stopinfo(x) for x in legs if x['mode'] != 'WALK']


        dures = [x['duration'] for x in legs]
        stopids = [x['from']['stop']['gtfsId'] if x['from']['stop'] else None for x in legs]

        stops3 = zip(stops2,it.count(0))

        tripleinfo = lambda x,y: (x, sum(dures[:stopids.index(x[0])]), sum(dures[:stopids.index(x[0])+1]) + y*180)
        triple = [tripleinfo(x,y) for x,y in stops3]

        if legs[-1]['mode'] == 'WALK':
            endwalk = legs[-1]['duration']
        else:
            endwalk = 0

        # startshift is walk time before first stop
        # endwalk is walk time from last stop to destination

        # check first possible starts
        firststop = triple[0]

        payload = STOPQ % (firststop[0][0], datte)
        reply = runQuery(payload)['data']['stop']['stoptimesForServiceDate'] 

        # check for start times
        starts = self.stopStarts(reply, firststop[0][1], firststop[0][2])
        ends = [x + firststop[2]- firststop[1] for x in starts]

        # loop over possible stops
        for stop,a,b in triple[1:]:
            payload = STOPQ % (stop[0], datte)
            reply = runQuery(payload)['data']['stop']['stoptimesForServiceDate'] 
            schedules = self.stopStarts(reply, stop[1], stop[2])

            ends = [next(it.dropwhile(lambda y: y < x, schedules)) for x in ends if x < schedules[-1]]
            ends = [x + b - a for x in ends]

        # Final info:
        starts = [x - startshift for x in starts]
        ends = [x + endwalk for x in ends]

        return [(a,b,b-a, 0,name) for a,b in zip(starts,ends)]
        


    def stopStarts(self, reply, shortName, headsign):
        starts = []
        for route in reply:
            if route['pattern']['route']['shortName']:
                if route['pattern']['route']['shortName']== shortName:
                    starts = route['stoptimes']
            elif route['pattern']['headsign'] == headsign:
                starts = route['stoptimes']

        starts = [x['scheduledDeparture'] for x in starts]
        starts.sort() # we sort scheduled departures, because they might not be inorder
        return starts
        
        
    # we take a singleroute, and check for stop data
    def analyseSingle(self,shortName,data,weekday=1):
                
        today = date.today()
        days = [today + timedelta(days=x) for x in range(1,8)]
        days = {x.isoweekday():x.strftime("%Y%m%d") for x in days}  
        
        gtfsId = data['gtfsId']
        
        payload = STOPQ % (gtfsId, days[weekday]) # 1 = monday
        temp = runQuery(payload)

        results = temp['data']['stop']['stoptimesForServiceDate']
        
        starts = next(x['stoptimes'] for x in results if x['pattern']['route']['shortName']==shortName)
        starts2 = [x['scheduledDeparture']-data['startShift'] for x in starts]
        
        return [(start,start+data['duration'],data['duration'], data['walkDistance'],shortName) for start in starts2]
        
        
    def makeResults(self, alltrips, source='A', dest='B'):
        # alltrips = [start,end,duration,walking,name]
        
        
        # we flatten the list of lists
        trips = [item for sublist in alltrips for item in sublist]
        
        # next we filter non-optimal routes out
        betterExists = lambda x: True if next((y for y in trips if x[0] < y[0] and y[1] <= x[1]),None) else False
        
        filteredlist = [x for x in trips if not betterExists(x)]
        # pprint.pprint(len(filteredlist)
        
        # unique names
        names = list(set(item[-1] for item in filteredlist))        
        names.sort()
        
        # we recreate list of lists for plotting purposes
        startsAll = [([int(item[0]/3600) for item in filteredlist if item[4]==x],x) for x in names]
        startsAll2 = [(np.array([y[0].count(x) for x in range(28)]),y[1]) for y in startsAll]
        
        durations = [(x,[item[2] for item in filteredlist if item[4]==x]) for x in names]
        durations = [self.styleLegendText(x,times) for x,times in durations]

        bottoms = [np.zeros(28)]

        for items in startsAll2[:-1]:
            bottoms.append(items[0] + bottoms[-1])
            
        xdata = np.arange(0, 28, 1)
        plt.figure(figsize=(20,10))

        for i, items in enumerate(startsAll2):
            c = cm.jet(i/len(startsAll2),0.8)
            plt.bar(xdata,items[0],1,bottom=bottoms[i], color=c)
        
        plt.ylabel('Number of departures from the first place')
        plt.xlabel('Starting time from address')
        plt.title('From place ' + source + ' to '+dest+ ' public transport, start times from starting point')

        xlabels = ['%s-%s' % (x,x+1) for x in xdata]
        plt.xticks(xdata + 0.5,xlabels)
        plt.legend(durations)
        plt.grid()
        plt.show()
        
        self.alltrips = alltrips
        
        # pprint.pprint(alltrips)
        
    def styleLegendText(self,x,times):
        if '+' in x:
            return '%s, duration: %.0f-%.0f min; median: %.0f min' % \
                   (x, min(times)/60, max(times)/60, st.median(times)/60)
        else:
            return '%s, duration:%.0f min' % (x, min(times)/60)

# %%
locs = ['Hakaniemi','Majurinkatu 6, Espoo','Keilaniementie 1, Espoo', 'Harakantie 4, Espoo']
poi = "Ukonvaaja 1, Espoo"

stuff = CheckRoutes(locs)

stuff.updatePlaces()
stuff.checkRoutes(poi)
# Out:
# From Ukonvaaja 1, Espoo to Harakantie 4, Espoo
# From Ukonvaaja 1, Espoo to Majurinkatu 6, Espoo
# From Ukonvaaja 1, Espoo to Hakaniemi
# From Ukonvaaja 1, Espoo to Keilaniementie 1, Espoo

# %% [markdown]
# ## Notes and ideas
#
# Program function:
# 1. Check routes on Friday morning, Friday evening, Saturday evening, Sunday evening
# 2. Check one stop schedule for one bus/connection
# 3. Draw results
#
# Results to be considered:
# - Connections per hour
# - Average duration of trip
# - Amount of walking distance
# - Does trip include more than one vehicle leg? (e.g. two busses or similar)

# %%
# Test case for getLocation
locs = ['Kamppi','Keilaniementie 1', 'Hakaniemi', 'Majurinkatu 6, Espoo','Harakantie 4, Espoo']
coords = []
for i in locs: 
    place = getLocation(i)
    coords.append(place)
    pprint.pprint ("%s location(s) %s" % (i, place))
# Out:
# ("Kamppi location(s) {'Kamppi, Helsinki, Suomi': (60.168438, 24.929283), "
#  "'Kamppi, kaukoliikenne, Helsinki, Suomi': (60.169586, 24.933375), 'Kampin "
#  "kappeli, Helsinki, Suomi': (60.169442, 24.935952)}")
# (
# "Keilaniementie 1 location(s) {'Keilaniementie, Espoo, Suomi': (60.173767, "
#  "24.828372), 'Keilaniementie 1, Espoo, Suomi': (60.17508, 24.831008), "
#  "'Keilaniementie 3, Espoo, Suomi': (60.174826, 24.829709), 'Keilaniementie 5, "
#  "Espoo, Suomi': (60.175442, 24.830047), 'Keilaniementie 4, Espoo, Suomi': "
#  '(60.175056, 24.828414)}')
# "Hakaniemi location(s) {'Hakaniemi, Helsinki, Suomi': (60.178909, 24.950318)}"
# (
# "Majurinkatu 6, Espoo location(s) {'Majurinkatu 8, Espoo, Suomi': (60.214392, "
#  "24.82583), 'Majurinkatu, Espoo, Suomi': (60.214737, 24.826395), 'Majurinkatu "
#  "5, Espoo, Suomi': (60.216366, 24.827361), 'Majurinkatu 1, Espoo, Suomi': "
#  '(60.212927, 24.826866)}')
# (
# ...

# %%
place2 = requests.get("http://api.digitransit.fi/geocoding/v1/reverse?point.lat=60.224776&point.lon=24.81327&size=1")
pprint.pprint(place2.json())
# Out:
# {'bbox': [24.81327, 60.224776, 24.81327, 60.224776],
#  'features': [{'geometry': {'coordinates': [24.81327, 60.224776],
#                             'type': 'Point'},
#                'properties': {'confidence': 1,
#                               'country': 'Suomi',
#                               'country_a': 'FIN',
#                               'country_gid': 'whosonfirst:country:85633143',
#                               'distance': 0,
#                               'gid': 'openstreetmap:address:way:322063296',
#                               'housenumber': '4',
#                               'id': 'way:322063296',
#                               'label': 'Harakantie 4, Espoo, Suomi',
#                               'layer': 'address',
#                               'localadmin': 'Espoo',
#                               'localadmin_gid': 'whosonfirst:localadmin:907198517',
#                               'locality': 'Espoo',
# ...
